# %% [markdown]
# # 1. Import and Install Dependencies

# %%
# !virtualenv env
# Out:
# created virtual environment CPython3.7.13.final.0-64 in 16364ms
#   creator CPython3Windows(dest=C:\Users\FreeComp\Desktop\sign_lang_detector\ActionDetectionforSignLanguage\env, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=C:\Users\FreeComp\AppData\Local\pypa\virtualenv)
#     added seed packages: pip==23.2.1, setuptools==68.0.0, wheel==0.41.3
#   activators BashActivator,BatchActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %%
cd C:\Users\FreeComp\Desktop\sign_lang_detector\ActionDetectionforSignLanguage\env\scripts
# Out:
# C:\Users\FreeComp\Desktop\sign_lang_detector\ActionDetectionforSignLanguage\env\scripts

# %%
# !activate

# %%
# !pip install tensorflow==2.4.1 tensorflow-gpu==2.4.1 opencv-python mediapipe scikit-learn matplotlib
# Out:
# Requirement already satisfied: tensorflow==2.4.1 in c:\users\freecomp\anaconda3\lib\site-packages (2.4.1)
# Requirement already satisfied: tensorflow-gpu==2.4.1 in c:\users\freecomp\anaconda3\lib\site-packages (2.4.1)
# Requirement already satisfied: opencv-python in c:\users\freecomp\anaconda3\lib\site-packages (4.6.0.66)
# Requirement already satisfied: mediapipe in c:\users\freecomp\appdata\roaming\python\python37\site-packages (0.9.0.1)
# Requirement already satisfied: scikit-learn in c:\users\freecomp\anaconda3\lib\site-packages (1.0.2)
# Requirement already satisfied: matplotlib in c:\users\freecomp\anaconda3\lib\site-packages (3.5.2)
# Requirement already satisfied: wheel~=0.35 in c:\users\freecomp\anaconda3\lib\site-packages (from tensorflow==2.4.1) (0.38.4)
# Collecting typing-extensions~=3.7.4
#   Using cached typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\freecomp\anaconda3\lib\site-packages (from tensorflow==2.4.1) (1.12.1)
# Requirement already satisfied: termcolor~=1.1.0 in c:\users\freecomp\anaconda3\lib\site-packages (from tensorflow==2.4.1) (1.1.0)
# Requirement already satisfied: h5py~=2.10.0 in c:\users\freecomp\anaconda3\lib\site-packages (from tensorflow==2.4.1) (2.10.0)
# Collecting six~=1.15.0
#   Using cached six-1.15.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\freecomp\anaconda3\lib\site-packages (from tensorflow==2.4.1) (3.3.0)
# Collecting grpcio~=1.32.0
#   Using cached grpcio-1.32.0-cp37-cp37m-win_amd64.whl (2.5 MB)
# Requirement already satisfied: tensorboard~=2.4 in c:\users\freecomp\anaconda3\lib\site-packages (from tensorflow==2.4.1) (2.10.1)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\freecomp\anaconda3\lib\site-packages (from tensorflow==2.4.1) (1.1.2)
# Requirement already satisfied: absl-py~=0.10 in c:\users\freecomp\anaconda3\lib\site-packages (from tensorflow==2.4.1) (0.15.0)
# Collecting flatbuffers~=1.12.0
#   Using cached flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\freecomp\anaconda3\lib\site-packages (from tensorflow==2.4.1) (1.6.3)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\freecomp\anaconda3\lib\site-packages (from tensorflow==2.4.1) (0.2.0)
# Collecting numpy~=1.19.2
#   Using cached numpy-1.19.5-cp37-cp37m-win_amd64.whl (13.2 MB)
# Collecting tensorflow-estimator<2.5.0,>=2.4.0
#   Using cached tensorflow_estimator-2.4.0-py2.py3-none-any.whl (462 kB)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\freecomp\anaconda3\lib\site-packages (from tensorflow==2.4.1) (3.20.3)
# Requirement already satisfied: gast==0.3.3 in c:\users\freecomp\anaconda3\lib\site-packages (from tensorflow==2.4.1) (0.3.3)
# Requirement already satisfied: opencv-contrib-python in c:\users\freecomp\appdata\roaming\python\python37\site-packages (from mediapipe) (4.8.1.78)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\freecomp\anaconda3\lib\site-packages (from mediapipe) (22.1.0)
# Collecting mediapipe
#   Using cached mediapipe-0.9.0-cp37-cp37m-win_amd64.whl (49.8 MB)
#   Using cached mediapipe-0.8.11-cp37-cp37m-win_amd64.whl (49.0 MB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\freecomp\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\freecomp\anaconda3\lib\site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\freecomp\anaconda3\lib\site-packages (from scikit-learn) (1.7.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\freecomp\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\freecomp\anaconda3\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\freecomp\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\freecomp\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\freecomp\anaconda3\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\freecomp\anaconda3\lib\site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\freecomp\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\freecomp\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow==2.4.1) (2.27.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\freecomp\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow==2.4.1) (2.2.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\freecomp\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow==2.4.1) (1.8.1)
# Collecting protobuf>=3.9.2
#   Using cached protobuf-3.19.6-cp37-cp37m-win_amd64.whl (896 kB)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\freecomp\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow==2.4.1) (65.5.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\freecomp\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow==2.4.1) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\freecomp\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow==2.4.1) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\freecomp\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow==2.4.1) (1.33.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\freecomp\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow==2.4.1) (3.3.4)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\freecomp\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.1) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\freecomp\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.1) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\freecomp\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.1) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\freecomp\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow==2.4.1) (1.3.1)
# Requirement already satisfied: importlib-metadata in c:\users\freecomp\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.4->tensorflow==2.4.1) (6.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\freecomp\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.1) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\freecomp\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.1) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\freecomp\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.1) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\freecomp\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.1) (2.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\freecomp\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.4->tensorflow==2.4.1) (2.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\freecomp\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.1) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\freecomp\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow==2.4.1) (3.2.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\freecomp\anaconda3\lib\site-packages (from importlib-metadata->markdown>=2.6.8->tensorboard~=2.4->tensorflow==2.4.1) (3.11.0)
# Installing collected packages: typing-extensions, tensorflow-estimator, flatbuffers, six, protobuf, numpy, grpcio, mediapipe
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.5.0
#     Uninstalling tensorflow-estimator-2.5.0:
#       Successfully uninstalled tensorflow-estimator-2.5.0
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 23.5.26
#     Uninstalling flatbuffers-23.5.26:
#       Successfully uninstalled flatbuffers-23.5.26
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.5
#     Uninstalling numpy-1.21.5:
#       Successfully uninstalled numpy-1.21.5
#   Rolling back uninstall of numpy
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy-1.21.5.dist-info\
#    from c:\users\freecomp\anaconda3\lib\site-packages\~umpy-1.21.5.dist-info
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\__config__.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\__config__.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\__init__.cython-30.pxd
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\__init__.cython-30.pxd
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\__init__.pxd
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\__init__.pxd
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\__init__.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\__init__.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\__pycache__\
#    from c:\users\freecomp\anaconda3\lib\site-packages\numpy\~_pycache__
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\_distributor_init.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\_distributor_init.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\_globals.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\_globals.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\_pytesttester.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\_pytesttester.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\char.pyi
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\char.pyi
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\compat\
#    from c:\users\freecomp\anaconda3\lib\site-packages\numpy\~ompat
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\conftest.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\conftest.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\__init__.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\__init__.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\__pycache__\
#    from c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\~_pycache__
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\_add_newdocs.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\_add_newdocs.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\_asarray.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\_asarray.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\_dtype.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\_dtype.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\_dtype_ctypes.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\_dtype_ctypes.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\_exceptions.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\_exceptions.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\_internal.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\_internal.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\_methods.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\_methods.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\_multiarray_tests.cp37-win_amd64.pyd
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\_multiarray_tests.cp37-win_amd64.pyd
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\_multiarray_umath.cp37-win_amd64.pyd
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\_multiarray_umath.cp37-win_amd64.pyd
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\_operand_flag_tests.cp37-win_amd64.pyd
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\_operand_flag_tests.cp37-win_amd64.pyd
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\_rational_tests.cp37-win_amd64.pyd
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\_rational_tests.cp37-win_amd64.pyd
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\_simd.cp37-win_amd64.pyd
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\_simd.cp37-win_amd64.pyd
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\_string_helpers.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\_string_helpers.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\_struct_ufunc_tests.cp37-win_amd64.pyd
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\_struct_ufunc_tests.cp37-win_amd64.pyd
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\_type_aliases.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\_type_aliases.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\_ufunc_config.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\_ufunc_config.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\_umath_tests.cp37-win_amd64.pyd
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\_umath_tests.cp37-win_amd64.pyd
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\arrayprint.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\arrayprint.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\cversions.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\cversions.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\defchararray.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\defchararray.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\einsumfunc.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\einsumfunc.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\fromnumeric.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\fromnumeric.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\function_base.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\function_base.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\generate_numpy_api.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\generate_numpy_api.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\getlimits.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\getlimits.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\include\numpy\
#    from c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\include\~umpy
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\lib\
#    from c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\~ib
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\machar.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\machar.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\memmap.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\memmap.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\multiarray.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\multiarray.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\numeric.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\numeric.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\numerictypes.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\numerictypes.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\overrides.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\overrides.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\records.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\records.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\setup.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\setup.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\setup_common.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\setup_common.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\shape_base.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\shape_base.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\__init__.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\__init__.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\__pycache__\
#    from c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\~_pycache__
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\_locales.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\_locales.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\data\astype_copy.pkl
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\data\astype_copy.pkl
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\data\recarray_from_file.fits
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\data\recarray_from_file.fits
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\examples\
#    from c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\~xamples
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test__exceptions.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test__exceptions.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_abc.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_abc.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_api.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_api.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_arrayprint.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_arrayprint.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_conversion_utils.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_conversion_utils.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_cpu_features.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_cpu_features.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_datetime.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_datetime.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_defchararray.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_defchararray.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_deprecations.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_deprecations.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_dtype.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_dtype.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_einsum.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_einsum.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_errstate.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_errstate.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_extint128.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_extint128.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_function_base.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_function_base.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_getlimits.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_getlimits.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_half.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_half.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_indexerrors.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_indexerrors.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_indexing.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_indexing.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_item_selection.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_item_selection.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_longdouble.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_longdouble.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_machar.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_machar.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_mem_overlap.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_mem_overlap.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_memmap.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_memmap.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_multiarray.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_multiarray.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_nditer.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_nditer.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_numeric.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_numeric.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_numerictypes.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_numerictypes.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_overrides.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_overrides.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_print.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_print.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_protocols.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_protocols.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_records.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_records.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_regression.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_regression.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_scalar_ctors.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_scalar_ctors.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_scalar_methods.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_scalar_methods.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_scalarbuffer.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_scalarbuffer.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_scalarinherit.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_scalarinherit.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_scalarmath.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_scalarmath.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_scalarprint.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_scalarprint.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_shape_base.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_shape_base.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_ufunc.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_ufunc.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_umath.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_umath.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_umath_accuracy.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_umath_accuracy.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_umath_complex.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_umath_complex.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\tests\test_unicode.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\tests\test_unicode.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\umath.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\umath.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\core\umath_tests.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\core\umath_tests.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\ctypeslib.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\ctypeslib.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\distutils\
#    from c:\users\freecomp\anaconda3\lib\site-packages\numpy\~istutils
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\doc\__init__.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\doc\__init__.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\doc\__pycache__\__init__.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\doc\__pycache__\__init__.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\doc\__pycache__\constants.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\doc\__pycache__\constants.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\doc\__pycache__\ufuncs.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\doc\__pycache__\ufuncs.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\doc\constants.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\doc\constants.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\doc\ufuncs.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\doc\ufuncs.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\dual.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\dual.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\f2py\
#    from c:\users\freecomp\anaconda3\lib\site-packages\numpy\~2py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\fft\
#    from c:\users\freecomp\anaconda3\lib\site-packages\numpy\~ft
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\__init__.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\__init__.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\__pycache__\__init__.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\__pycache__\__init__.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\__pycache__\_datasource.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\__pycache__\_datasource.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\__pycache__\_iotools.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\__pycache__\_iotools.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\__pycache__\_version.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\__pycache__\_version.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\__pycache__\arraypad.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\__pycache__\arraypad.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\__pycache__\arraysetops.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\__pycache__\arraysetops.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\__pycache__\arrayterator.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\__pycache__\arrayterator.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\__pycache__\format.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\__pycache__\format.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\__pycache__\function_base.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\__pycache__\function_base.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\__pycache__\histograms.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\__pycache__\histograms.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\__pycache__\index_tricks.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\__pycache__\index_tricks.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\__pycache__\mixins.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\__pycache__\mixins.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\__pycache__\nanfunctions.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\__pycache__\nanfunctions.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\__pycache__\npyio.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\__pycache__\npyio.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\__pycache__\polynomial.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\__pycache__\polynomial.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\__pycache__\recfunctions.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\__pycache__\recfunctions.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\__pycache__\scimath.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\__pycache__\scimath.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\__pycache__\setup.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\__pycache__\setup.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\__pycache__\shape_base.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\__pycache__\shape_base.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\__pycache__\stride_tricks.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\__pycache__\stride_tricks.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\__pycache__\twodim_base.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\__pycache__\twodim_base.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\__pycache__\type_check.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\__pycache__\type_check.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\__pycache__\ufunclike.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\__pycache__\ufunclike.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\__pycache__\user_array.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\__pycache__\user_array.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\__pycache__\utils.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\__pycache__\utils.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\_datasource.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\_datasource.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\_iotools.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\_iotools.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\_version.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\_version.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\arraypad.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\arraypad.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\arraysetops.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\arraysetops.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\arrayterator.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\arrayterator.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\format.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\format.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\function_base.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\function_base.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\histograms.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\histograms.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\index_tricks.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\index_tricks.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\mixins.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\mixins.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\nanfunctions.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\npyio.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\npyio.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\polynomial.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\polynomial.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\recfunctions.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\recfunctions.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\scimath.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\scimath.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\setup.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\setup.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\shape_base.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\shape_base.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\stride_tricks.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\stride_tricks.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\__init__.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\__init__.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\__pycache__\__init__.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\__pycache__\__init__.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\__pycache__\test__datasource.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\__pycache__\test__datasource.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\__pycache__\test__iotools.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\__pycache__\test__iotools.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\__pycache__\test__version.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\__pycache__\test__version.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\__pycache__\test_arraypad.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\__pycache__\test_arraypad.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\__pycache__\test_arraysetops.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\__pycache__\test_arraysetops.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\__pycache__\test_arrayterator.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\__pycache__\test_arrayterator.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\__pycache__\test_format.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\__pycache__\test_format.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\__pycache__\test_function_base.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\__pycache__\test_function_base.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\__pycache__\test_histograms.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\__pycache__\test_histograms.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\__pycache__\test_index_tricks.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\__pycache__\test_index_tricks.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\__pycache__\test_io.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\__pycache__\test_io.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\__pycache__\test_mixins.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\__pycache__\test_mixins.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\__pycache__\test_nanfunctions.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\__pycache__\test_nanfunctions.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\__pycache__\test_packbits.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\__pycache__\test_packbits.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\__pycache__\test_polynomial.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\__pycache__\test_polynomial.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\__pycache__\test_recfunctions.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\__pycache__\test_recfunctions.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\__pycache__\test_regression.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\__pycache__\test_regression.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\__pycache__\test_shape_base.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\__pycache__\test_shape_base.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\__pycache__\test_stride_tricks.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\__pycache__\test_stride_tricks.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\__pycache__\test_twodim_base.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\__pycache__\test_twodim_base.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\__pycache__\test_type_check.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\__pycache__\test_type_check.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\__pycache__\test_ufunclike.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\__pycache__\test_ufunclike.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\__pycache__\test_utils.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\__pycache__\test_utils.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\data\
#    from c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\~ata
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\test__datasource.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\test__datasource.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\test__iotools.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\test__iotools.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\test__version.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\test__version.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\test_arraypad.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\test_arraypad.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\test_arraysetops.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\test_arraysetops.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\test_arrayterator.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\test_arrayterator.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\test_format.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\test_format.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\test_function_base.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\test_function_base.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\test_histograms.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\test_histograms.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\test_index_tricks.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\test_index_tricks.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\test_io.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\test_io.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\test_mixins.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\test_mixins.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\test_nanfunctions.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\test_nanfunctions.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\test_packbits.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\test_packbits.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\test_polynomial.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\test_polynomial.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\test_recfunctions.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\test_recfunctions.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\test_regression.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\test_regression.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\test_shape_base.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\test_shape_base.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\test_stride_tricks.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\test_stride_tricks.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\test_twodim_base.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\test_twodim_base.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\test_type_check.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\test_type_check.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\test_ufunclike.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\test_ufunclike.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\tests\test_utils.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\tests\test_utils.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\twodim_base.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\twodim_base.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\type_check.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\type_check.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\ufunclike.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\ufunclike.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\user_array.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\user_array.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\lib\utils.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\lib\utils.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\license.txt
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\license.txt
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\linalg\
#    from c:\users\freecomp\anaconda3\lib\site-packages\numpy\~inalg
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\ma\
#    from c:\users\freecomp\anaconda3\lib\site-packages\numpy\~a
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\matlib.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\matlib.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\matrixlib\
#    from c:\users\freecomp\anaconda3\lib\site-packages\numpy\~atrixlib
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\polynomial\
#    from c:\users\freecomp\anaconda3\lib\site-packages\numpy\~olynomial
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\random\
#    from c:\users\freecomp\anaconda3\lib\site-packages\numpy\~andom
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\rec.pyi
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\rec.pyi
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\setup.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\setup.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\testing\__init__.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\testing\__init__.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\testing\__pycache__\
#    from c:\users\freecomp\anaconda3\lib\site-packages\numpy\testing\~_pycache__
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\testing\_private\
#    from c:\users\freecomp\anaconda3\lib\site-packages\numpy\testing\~private
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\testing\print_coercion_tables.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\testing\print_coercion_tables.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\testing\setup.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\testing\setup.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\testing\tests\__init__.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\testing\tests\__init__.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\testing\tests\__pycache__\__init__.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\testing\tests\__pycache__\__init__.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\testing\tests\__pycache__\test_doctesting.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\testing\tests\__pycache__\test_doctesting.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\testing\tests\__pycache__\test_utils.cpython-37.pyc
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\testing\tests\__pycache__\test_utils.cpython-37.pyc
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\testing\tests\test_doctesting.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\testing\tests\test_doctesting.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\testing\tests\test_utils.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\testing\tests\test_utils.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\testing\utils.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\testing\utils.py
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\tests\
#    from c:\users\freecomp\anaconda3\lib\site-packages\numpy\~ests
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\typing\
#    from c:\users\freecomp\anaconda3\lib\site-packages\numpy\~yping
#   Moving to c:\users\freecomp\anaconda3\lib\site-packages\numpy\version.py
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-50ph97em\version.py
#   Moving to c:\users\freecomp\anaconda3\scripts\f2py.exe
#    from C:\Users\FreeComp\AppData\Local\Temp\pip-uninstall-s67eu8r0\f2py.exe
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\FreeComp\\anaconda3\\Lib\\site-packages\\numpy\\.libs\\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll'
# Consider using the `--user` option or check the permissions.

# %%
# !pip install --user mediapipe
# Out:
# Requirement already satisfied: mediapipe in c:\users\freecomp\appdata\roaming\python\python37\site-packages (0.9.0.1)
# Requirement already satisfied: protobuf<4,>=3.11 in c:\users\freecomp\anaconda3\lib\site-packages (from mediapipe) (3.19.6)
# Requirement already satisfied: absl-py in c:\users\freecomp\anaconda3\lib\site-packages (from mediapipe) (0.15.0)
# Requirement already satisfied: opencv-contrib-python in c:\users\freecomp\appdata\roaming\python\python37\site-packages (from mediapipe) (4.8.1.78)
# Collecting flatbuffers>=2.0
#   Using cached flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: matplotlib in c:\users\freecomp\anaconda3\lib\site-packages (from mediapipe) (3.5.2)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\freecomp\anaconda3\lib\site-packages (from mediapipe) (22.1.0)
# Requirement already satisfied: numpy in c:\users\freecomp\anaconda3\lib\site-packages (from mediapipe) (1.21.5)
# Requirement already satisfied: six in c:\users\freecomp\anaconda3\lib\site-packages (from absl-py->mediapipe) (1.15.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\freecomp\anaconda3\lib\site-packages (from matplotlib->mediapipe) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\freecomp\anaconda3\lib\site-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\freecomp\anaconda3\lib\site-packages (from matplotlib->mediapipe) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\freecomp\anaconda3\lib\site-packages (from matplotlib->mediapipe) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\freecomp\anaconda3\lib\site-packages (from matplotlib->mediapipe) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\freecomp\anaconda3\lib\site-packages (from matplotlib->mediapipe) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\freecomp\anaconda3\lib\site-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: typing-extensions in c:\users\freecomp\anaconda3\lib\site-packages (from kiwisolver>=1.0.1->matplotlib->mediapipe) (4.1.1)
# Installing collected packages: flatbuffers
# Successfully installed flatbuffers-23.5.26
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.4.1 requires flatbuffers~=1.12.0, but you have flatbuffers 23.5.26 which is incompatible.
# tensorflow 2.4.1 requires grpcio~=1.32.0, but you have grpcio 1.42.0 which is incompatible.
# tensorflow 2.4.1 requires numpy~=1.19.2, but you have numpy 1.21.5 which is incompatible.
# tensorflow 2.4.1 requires typing-extensions~=3.7.4, but you have typing-extensions 4.1.1 which is incompatible.
# tensorflow-gpu 2.4.1 requires flatbuffers~=1.12.0, but you have flatbuffers 23.5.26 which is incompatible.
# tensorflow-gpu 2.4.1 requires grpcio~=1.32.0, but you have grpcio 1.42.0 which is incompatible.
# tensorflow-gpu 2.4.1 requires numpy~=1.19.2, but you have numpy 1.21.5 which is incompatible.
# tensorflow-gpu 2.4.1 requires typing-extensions~=3.7.4, but you have typing-extensions 4.1.1 which is incompatible.

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time

# %%
# !pip3 install --user mediapipe
# Out:
# Requirement already satisfied: mediapipe in c:\users\freecomp\appdata\roaming\python\python37\site-packages (0.9.0.1)
# Requirement already satisfied: protobuf<4,>=3.11 in c:\users\freecomp\anaconda3\lib\site-packages (from mediapipe) (3.19.6)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\freecomp\appdata\roaming\python\python37\site-packages (from mediapipe) (23.5.26)
# Requirement already satisfied: absl-py in c:\users\freecomp\anaconda3\lib\site-packages (from mediapipe) (0.15.0)
# Requirement already satisfied: numpy in c:\users\freecomp\anaconda3\lib\site-packages (from mediapipe) (1.21.5)
# Requirement already satisfied: matplotlib in c:\users\freecomp\anaconda3\lib\site-packages (from mediapipe) (3.5.2)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\freecomp\anaconda3\lib\site-packages (from mediapipe) (22.1.0)
# Requirement already satisfied: opencv-contrib-python in c:\users\freecomp\appdata\roaming\python\python37\site-packages (from mediapipe) (4.8.1.78)
# Requirement already satisfied: six in c:\users\freecomp\anaconda3\lib\site-packages (from absl-py->mediapipe) (1.15.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\freecomp\anaconda3\lib\site-packages (from matplotlib->mediapipe) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\freecomp\anaconda3\lib\site-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\freecomp\anaconda3\lib\site-packages (from matplotlib->mediapipe) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\freecomp\anaconda3\lib\site-packages (from matplotlib->mediapipe) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\freecomp\anaconda3\lib\site-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\freecomp\anaconda3\lib\site-packages (from matplotlib->mediapipe) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\freecomp\anaconda3\lib\site-packages (from matplotlib->mediapipe) (9.2.0)
# Requirement already satisfied: typing-extensions in c:\users\freecomp\anaconda3\lib\site-packages (from kiwisolver>=1.0.1->matplotlib->mediapipe) (4.1.1)

# %%
import mediapipe as mp

# %% [markdown]
# # 2. Keypoints using MP Holistic

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
results
# Out:
# mediapipe.python.solution_base.SolutionOutputs

# %%
results.face_landmarks
# Out:
# landmark {
#   x: 0.52424616
#   y: 0.7222199
#   z: -0.039590847
# }
# landmark {
#   x: 0.5248682
#   y: 0.65346694
#   z: -0.072117485
# }
# landmark {
#   x: 0.52251935
#   y: 0.674798
#   z: -0.037760247
# }
# landmark {
#   x: 0.50832695
#   y: 0.58830154
#   z: -0.055718083
# }
# landmark {
#   x: 0.5244526
#   y: 0.6326437
#   z: -0.0768018
# }
# landmark {
#   x: 0.52244294
#   y: 0.6059536
#   z: -0.07153546
# }
# landmark {
#   x: 0.5161948
#   y: 0.542781
#   z: -0.034972485
# }
# landmark {
#   x: 0.41117772
#   y: 0.5453512
#   z: 0.006542456
# }
# landmark {
#   x: 0.5135594
#   y: 0.49405128
#   z: -0.026344562
# }
# landmark {
#   x: 0.5130705
#   y: 0.46609566
#   z: -0.02939039
# }
# landmark {
#   x: 0.50772476
#   y: 0.36703584
#   z: -0.015264141
# }
# landmark {
#   x: 0.524426
#   y: 0.7322016
#   z: -0.037581775
# }
# landmark {
#   x: 0.52409595
#   y: 0.73947465
#   z: -0.032811057
# }
# landmark {
#   x: 0.5233867
#   y: 0.74213207
#   z: -0.026589703
# }
# landmark {
#   x: 0.5240704
#   y: 0.7465982
#   z: -0.025980877
# }
# landmark {
#   x: 0.5246743
#   y: 0.7549056
#   z: -0.02805567
# }
# landmark {
#   x: 0.5251394
#   y: 0.76548934
#   z: -0.030493874
# }
# landmark {
#   x: 0.5252786
#   y: 0.7768988
#   z: -0.028000629
# }
# landmark {
#   x: 0.5244034
#   y: 0.7950697
#   z: -0.0141191175
# }
# landmark {
#   x: 0.5242681
#   y: 0.6640098
#   z: -0.0651639
# }
# landmark {
#   x: 0.51046044
#   y: 0.6635506
#   z: -0.047964178
# }
# landmark {
#   x: 0.34953386
#   y: 0.4708066
#   z: 0.0646728
# }
# landmark {
#   x: 0.45225686
#   y: 0.5608033
#   z: -0.0034942282
# }
# landmark {
#   x: 0.43857616
#   y: 0.56335706
#   z: -0.0038441531
# }
# landmark {
#   x: 0.425111
#   y: 0.56305987
#   z: -0.0013057294
# }
# landmark {
#   x: 0.40595615
#   y: 0.5529124
#   z: 0.008188966
# }
# landmark {
#   x: 0.46378148
#   y: 0.55451775
#   z: -0.0002589368
# }
# landmark {
#   x: 0.43343422
#   y: 0.51221126
#   z: -0.011120318
# }
# landmark {
#   x: 0.4480128
#   y: 0.5127334
#   z: -0.008929969
# }
# landmark {
#   x: 0.41949952
#   y: 0.51571816
#   z: -0.0077930097
# }
# landmark {
#   x: 0.40983334
#   y: 0.5227312
#   z: -0.0028638605
# }
# landmark {
#   x: 0.3952725
#   y: 0.5663465
#   z: 0.014306426
# }
# landmark {
#   x: 0.47348517
#   y: 0.8291195
#   z: -0.0035624676
# }
# landmark {
#   x: 0.40589395
#   y: 0.54065996
#   z: 0.010465472
# }
# landmark {
#   x: 0.34935212
#   y: 0.55864173
#   z: 0.07015471
# }
# landmark {
#   x: 0.37802082
#   y: 0.55306625
#   z: 0.026370598
# }
# landmark {
#   x: 0.44885603
#   y: 0.6425808
#   z: -0.015638793
# }
# landmark {
#   x: 0.5075731
#   y: 0.7201511
#   z: -0.039681256
# }
# landmark {
#   x: 0.5097351
#   y: 0.74000835
#   z: -0.032697365
# }
# landmark {
#   x: 0.48999456
#   y: 0.727596
#   z: -0.033775825
# }
# landmark {
#   x: 0.47841242
#   y: 0.73650795
#   z: -0.025389884
# }
# landmark {
#   x: 0.49679855
#   y: 0.74221057
#   z: -0.029287688
# }
# landmark {
#   x: 0.48649454
#   y: 0.74467987
#   z: -0.02131557
# }
# landmark {
#   x: 0.46086642
#   y: 0.7674932
#   z: -0.005884175
# }
# landmark {
#   x: 0.5133023
#   y: 0.6534689
#   z: -0.071981005
# }
# landmark {
#   x: 0.51101714
#   y: 0.63370246
#   z: -0.07649444
# }
# landmark {
#   x: 0.3853909
#   y: 0.50058997
#   z: -0.0006110821
# }
# landmark {
#   x: 0.4737182
#   y: 0.5908771
#   z: -0.015314573
# }
# landmark {
#   x: 0.4779214
#   y: 0.6507214
#   z: -0.04227488
# }
# landmark {
#   x: 0.47586808
#   y: 0.6403027
#   z: -0.03833281
# }
# landmark {
#   x: 0.40582907
#   y: 0.6435281
#   z: -0.0027931735
# }
# landmark {
#   x: 0.5097843
#   y: 0.6089027
#   z: -0.0687141
# }
# landmark {
#   x: 0.42057717
#   y: 0.47651327
#   z: -0.01999591
# }
# landmark {
#   x: 0.39999354
#   y: 0.48490888
#   z: -0.011466742
# }
# landmark {
#   x: 0.3640091
#   y: 0.43272382
#   z: 0.039143566
# }
# landmark {
#   x: 0.48387787
#   y: 0.49011087
#   z: -0.02544377
# }
# landmark {
#   x: 0.46078643
#   y: 0.51804763
#   z: -0.0035336304
# }
# landmark {
#   x: 0.44967502
#   y: 0.74988574
#   z: -0.0041524316
# }
# landmark {
#   x: 0.37214422
#   y: 0.74311024
#   z: 0.10939292
# }
# landmark {
#   x: 0.488194
#   y: 0.66109973
#   z: -0.03577571
# }
# landmark {
#   x: 0.5002444
#   y: 0.66696024
#   z: -0.03527622
# }
# landmark {
#   x: 0.4652653
#   y: 0.7494553
#   z: -0.0049494435
# }
# landmark {
#   x: 0.47098485
#   y: 0.74759793
#   z: -0.0080133425
# }
# landmark {
#   x: 0.39036676
#   y: 0.4711008
#   z: -0.005968084
# }
# landmark {
#   x: 0.4772115
#   y: 0.6597849
#   z: -0.034587108
# }
# landmark {
#   x: 0.4481524
#   y: 0.47661453
#   z: -0.024945054
# }
# landmark {
#   x: 0.4449838
#   y: 0.45905966
#   z: -0.028117247
# }
# landmark {
#   x: 0.42490366
#   y: 0.380283
#   z: -0.007267568
# }
# landmark {
#   x: 0.3775135
#   y: 0.4510037
#   z: 0.013094
# }
# landmark {
#   x: 0.43662572
#   y: 0.41799992
#   z: -0.018416094
# }
# landmark {
#   x: 0.3751947
#   y: 0.49181017
#   z: 0.010170124
# }
# landmark {
#   x: 0.3624134
#   y: 0.48205835
#   z: 0.035491657
# }
# landmark {
#   x: 0.50870365
#   y: 0.73195416
#   z: -0.037958108
# }
# landmark {
#   x: 0.49416295
#   y: 0.736612
#   z: -0.032250594
# }
# landmark {
#   x: 0.48276848
#   y: 0.7409555
#   z: -0.024597984
# }
# landmark {
#   x: 0.49184117
#   y: 0.664561
#   z: -0.032266237
# }
# landmark {
#   x: 0.468436
#   y: 0.74887246
#   z: -0.0064196526
# }
# landmark {
#   x: 0.47469875
#   y: 0.7513634
#   z: -0.014012993
# }
# landmark {
#   x: 0.4719042
#   y: 0.74635684
#   z: -0.008269703
# }
# landmark {
#   x: 0.49655023
#   y: 0.65369517
#   z: -0.054396488
# }
# landmark {
#   x: 0.48828337
#   y: 0.74319285
#   z: -0.018890737
# }
# landmark {
#   x: 0.49884662
#   y: 0.7425686
#   z: -0.023562001
# }
# landmark {
#   x: 0.51072025
#   y: 0.7423278
#   z: -0.026893605
# }
# landmark {
#   x: 0.5064998
#   y: 0.7959603
#   z: -0.015461698
# }
# landmark {
#   x: 0.5085272
#   y: 0.7766122
#   z: -0.029164653
# }
# landmark {
#   x: 0.5092708
#   y: 0.7646401
#   z: -0.031235496
# }
# landmark {
#   x: 0.50986445
#   y: 0.754005
#   z: -0.028563473
# }
# landmark {
#   x: 0.5105168
#   y: 0.7469841
#   z: -0.026313882
# }
# landmark {
#   x: 0.4869282
#   y: 0.74707514
#   z: -0.018320376
# }
# landmark {
#   x: 0.4852494
#   y: 0.74963856
#   z: -0.020672496
# }
# landmark {
#   x: 0.48264974
#   y: 0.75517976
#   z: -0.022740625
# }
# landmark {
#   x: 0.48028398
#   y: 0.7622145
#   z: -0.020506643
# }
# landmark {
#   x: 0.46501654
#   y: 0.71405566
#   z: -0.021540105
# }
# landmark {
#   x: 0.3504629
#   y: 0.6473571
#   z: 0.12734087
# }
# landmark {
#   x: 0.52332866
#   y: 0.6681519
#   z: -0.047240235
# }
# landmark {
#   x: 0.47977668
#   y: 0.74735093
#   z: -0.012447516
# }
# landmark {
#   x: 0.47764024
#   y: 0.7485394
#   z: -0.0139405755
# }
# landmark {
#   x: 0.50534403
#   y: 0.6757915
#   z: -0.036001347
# }
# landmark {
#   x: 0.4822452
#   y: 0.6718249
#   z: -0.023750817
# }
# landmark {
#   x: 0.50296724
#   y: 0.6715877
#   z: -0.0358185
# }
# landmark {
#   x: 0.45927805
#   y: 0.6035885
#   z: -0.011994279
# }
# landmark {
#   x: 0.43731847
#   y: 0.6183872
#   z: -0.009814898
# }
# landmark {
#   x: 0.47345096
#   y: 0.6495363
#   z: -0.030714452
# }
# landmark {
#   x: 0.38819852
#   y: 0.4018008
#   z: 0.013400639
# }
# landmark {
#   x: 0.4012353
#   y: 0.4286607
#   z: -0.0043899585
# }
# landmark {
#   x: 0.41443157
#   y: 0.4594713
#   z: -0.018424105
# }
# landmark {
#   x: 0.47302797
#   y: 0.7787591
#   z: -0.01111238
# }
# landmark {
#   x: 0.47897342
#   y: 0.4623266
#   z: -0.031452592
# }
# landmark {
#   x: 0.47195464
#   y: 0.41585267
#   z: -0.024812447
# }
# landmark {
#   x: 0.4635394
#   y: 0.3699859
#   z: -0.016793016
# }
# landmark {
#   x: 0.41312158
#   y: 0.5599316
#   z: 0.0035207744
# }
# landmark {
#   x: 0.38093233
#   y: 0.5813728
#   z: 0.020590119
# }
# landmark {
#   x: 0.4711558
#   y: 0.5483964
#   z: 0.002179399
# }
# landmark {
#   x: 0.39305592
#   y: 0.528088
#   z: 0.007575872
# }
# landmark {
#   x: 0.48344576
#   y: 0.57706594
#   z: -0.019364879
# }
# landmark {
#   x: 0.4870681
#   y: 0.642357
#   z: -0.054812897
# }
# landmark {
#   x: 0.3660816
#   y: 0.5957737
#   z: 0.033896726
# }
# landmark {
#   x: 0.39201388
#   y: 0.59515035
#   z: 0.009163087
# }
# landmark {
#   x: 0.41117975
#   y: 0.60166794
#   z: -0.001377726
# }
# landmark {
#   x: 0.437801
#   y: 0.59696394
#   z: -0.0048237746
# }
# landmark {
#   x: 0.45697302
#   y: 0.58731025
#   z: -0.0059616677
# }
# landmark {
#   x: 0.47140858
#   y: 0.5766489
#   z: -0.0078857355
# }
# landmark {
#   x: 0.5026872
#   y: 0.5487757
#   z: -0.03141255
# }
# landmark {
#   x: 0.37117678
#   y: 0.6378632
#   z: 0.030448075
# }
# landmark {
#   x: 0.38051873
#   y: 0.5249362
#   z: 0.012893572
# }
# landmark {
#   x: 0.51747316
#   y: 0.66360354
#   z: -0.06526392
# }
# landmark {
#   x: 0.47681642
#   y: 0.6100904
#   z: -0.020915473
# }
# landmark {
#   x: 0.3416655
#   y: 0.55802387
#   z: 0.115284085
# }
# landmark {
#   x: 0.48222095
#   y: 0.56480324
#   z: -0.008933543
# }
# landmark {
#   x: 0.47138676
#   y: 0.6511432
#   z: -0.017063702
# }
# landmark {
#   x: 0.40120193
#   y: 0.5419547
#   z: 0.012618983
# }
# landmark {
#   x: 0.48505157
#   y: 0.62975305
#   z: -0.04969753
# }
# landmark {
#   x: 0.3585857
#   y: 0.69459134
#   z: 0.121946216
# }
# landmark {
#   x: 0.47053877
#   y: 0.5408858
#   z: 0.0051479605
# }
# landmark {
#   x: 0.49714428
#   y: 0.6171704
#   z: -0.06184857
# }
# landmark {
#   x: 0.40968537
#   y: 0.7882974
#   z: 0.04020855
# }
# landmark {
#   x: 0.40949768
#   y: 0.8092714
#   z: 0.06509038
# }
# landmark {
#   x: 0.355224
#   y: 0.64357287
#   z: 0.0780143
# }
# landmark {
#   x: 0.3900911
#   y: 0.7626384
#   z: 0.055457085
# }
# landmark {
#   x: 0.3550489
#   y: 0.5175151
#   z: 0.056519
# }
# landmark {
#   x: 0.47111768
#   y: 0.84811985
#   z: 0.004271855
# }
# landmark {
#   x: 0.51804894
#   y: 0.6677228
#   z: -0.046857215
# }
# landmark {
#   x: 0.46475068
#   y: 0.6257914
#   z: -0.016817754
# }
# landmark {
#   x: 0.36538085
#   y: 0.5574384
#   z: 0.038554523
# }
# landmark {
#   x: 0.42569172
#   y: 0.5509035
#   z: -0.00036076707
# }
# landmark {
#   x: 0.43789566
#   y: 0.552036
#   z: -0.0025002907
# }
# landmark {
#   x: 0.4714099
#   y: 0.7556434
#   z: -0.01187145
# }
# landmark {
#   x: 0.37610584
#   y: 0.67785275
#   z: 0.035539206
# }
# landmark {
#   x: 0.49638084
#   y: 0.8715786
#   z: 0.011182408
# }
# landmark {
#   x: 0.4527823
#   y: 0.84943366
#   z: 0.033101782
# }
# landmark {
#   x: 0.43291536
#   y: 0.8335079
#   z: 0.04683717
# }
# landmark {
#   x: 0.51064795
#   y: 0.4162051
#   z: -0.02346693
# }
# landmark {
#   x: 0.5242903
#   y: 0.8727252
#   z: 0.010599882
# }
# landmark {
#   x: 0.4494763
#   y: 0.5499755
#   z: -0.0017415616
# }
# landmark {
#   x: 0.4601709
#   y: 0.54588497
#   z: 0.001256285
# }
# landmark {
#   x: 0.46696967
#   y: 0.5431836
#   z: 0.004721957
# }
# landmark {
#   x: 0.36900717
#   y: 0.52123165
#   z: 0.025585957
# }
# landmark {
#   x: 0.45850745
#   y: 0.52952385
#   z: -0.0014802024
# }
# landmark {
#   x: 0.44648606
#   y: 0.52595425
#   z: -0.005023806
# }
# landmark {
#   x: 0.43476996
#   y: 0.52565163
#   z: -0.0056996527
# }
# landmark {
#   x: 0.42269367
#   y: 0.529125
#   z: -0.003333283
# }
# landmark {
#   x: 0.41480148
#   y: 0.53410405
#   z: 0.0004053529
# }
# landmark {
#   x: 0.34270757
#   y: 0.51003695
#   z: 0.09289361
# }
# landmark {
#   x: 0.41718122
#   y: 0.54824495
#   z: 0.0033078382
# }
# landmark {
#   x: 0.5227792
#   y: 0.6899953
#   z: -0.035045825
# }
# landmark {
#   x: 0.47740898
#   y: 0.70123273
#   z: -0.026628846
# }
# landmark {
#   x: 0.48814034
#   y: 0.6577816
#   z: -0.04078966
# }
# landmark {
#   x: 0.50432986
#   y: 0.6930585
#   z: -0.03614452
# }
# landmark {
#   x: 0.5141112
#   y: 0.5184855
#   z: -0.025416186
# }
# landmark {
#   x: 0.43021247
#   y: 0.81269175
#   z: 0.028946908
# }
# landmark {
#   x: 0.4499345
#   y: 0.8307728
#   z: 0.017339284
# }
# landmark {
#   x: 0.49636516
#   y: 0.8597473
#   z: -0.006091773
# }
# landmark {
#   x: 0.3899045
#   y: 0.7814548
#   z: 0.08852079
# }
# landmark {
#   x: 0.46688423
#   y: 0.5360476
#   z: 0.0024059205
# }
# landmark {
#   x: 0.49522498
#   y: 0.58103675
#   z: -0.036676366
# }
# landmark {
#   x: 0.5256151
#   y: 0.86040664
#   z: -0.0061251996
# }
# landmark {
#   x: 0.47356525
#   y: 0.8628373
#   z: 0.018970601
# }
# landmark {
#   x: 0.36255366
#   y: 0.6871109
#   z: 0.07695594
# }
# landmark {
#   x: 0.49787307
#   y: 0.74685097
#   z: -0.02303916
# }
# landmark {
#   x: 0.49623945
#   y: 0.75188065
#   z: -0.025641635
# }
# landmark {
#   x: 0.49454236
#   y: 0.76014674
#   z: -0.028049624
# }
# landmark {
#   x: 0.493104
#   y: 0.770938
#   z: -0.02615091
# }
# landmark {
#   x: 0.4880697
#   y: 0.7889538
#   z: -0.015445148
# }
# landmark {
#   x: 0.477154
#   y: 0.74637216
#   z: -0.0142415995
# }
# landmark {
#   x: 0.47347277
#   y: 0.7453612
#   z: -0.014888912
# }
# landmark {
#   x: 0.46948543
#   y: 0.7429274
#   z: -0.015426241
# }
# landmark {
#   x: 0.45489398
#   y: 0.7309265
#   z: -0.013655865
# }
# landmark {
#   x: 0.3967289
#   y: 0.6871587
#   z: 0.010539834
# }
# landmark {
#   x: 0.4932039
#   y: 0.5615505
#   z: -0.024365235
# }
# landmark {
#   x: 0.48221847
#   y: 0.52538604
#   z: -0.0027413184
# }
# landmark {
#   x: 0.47314143
#   y: 0.53012323
#   z: 0.00081339467
# }
# landmark {
#   x: 0.47936705
#   y: 0.74368364
#   z: -0.012764562
# }
# landmark {
#   x: 0.3966197
#   y: 0.73485863
#   z: 0.03044281
# }
# landmark {
#   x: 0.4957405
#   y: 0.5226608
#   z: -0.01858428
# }
# landmark {
#   x: 0.48003328
#   y: 0.8091194
#   z: -0.008355624
# }
# landmark {
#   x: 0.52024233
#   y: 0.58441794
#   z: -0.058756873
# }
# landmark {
#   x: 0.50541586
#   y: 0.56953144
#   z: -0.04473438
# }
# landmark {
#   x: 0.51823276
#   y: 0.5644723
#   z: -0.046379346
# }
# landmark {
#   x: 0.4868842
#   y: 0.6129831
#   z: -0.037341934
# }
# landmark {
#   x: 0.52581686
#   y: 0.8414768
#   z: -0.0139489565
# }
# landmark {
#   x: 0.52509004
#   y: 0.81711745
#   z: -0.014081931
# }
# landmark {
#   x: 0.50226194
#   y: 0.8178337
#   z: -0.013622999
# }
# landmark {
#   x: 0.44682983
#   y: 0.776412
#   z: 0.0010956092
# }
# landmark {
#   x: 0.46053568
#   y: 0.6681451
#   z: -0.014886681
# }
# landmark {
#   x: 0.46214017
#   y: 0.79566085
#   z: -0.0031483036
# }
# landmark {
#   x: 0.42784715
#   y: 0.6675714
#   z: -0.01218831
# }
# landmark {
#   x: 0.44836372
#   y: 0.6892181
#   z: -0.014201741
# }
# landmark {
#   x: 0.41702014
#   y: 0.70088154
#   z: -0.0030397992
# }
# landmark {
#   x: 0.49819854
#   y: 0.8412912
#   z: -0.013307833
# }
# landmark {
#   x: 0.47829208
#   y: 0.62510633
#   z: -0.028540423
# }
# landmark {
#   x: 0.43466744
#   y: 0.7914437
#   z: 0.013372982
# }
# landmark {
#   x: 0.45410448
#   y: 0.81159055
#   z: 0.0068380004
# }
# landmark {
#   x: 0.4347797
#   y: 0.75291204
#   z: 0.0012710743
# }
# landmark {
#   x: 0.38137853
#   y: 0.7114067
#   z: 0.04116778
# }
# landmark {
#   x: 0.41635883
#   y: 0.75598335
#   z: 0.013846003
# }
# landmark {
#   x: 0.3724704
#   y: 0.726694
#   z: 0.07187732
# }
# landmark {
#   x: 0.43841603
#   y: 0.71678483
#   z: -0.009523929
# }
# landmark {
#   x: 0.48606172
#   y: 0.5952234
#   z: -0.028189516
# }
# landmark {
#   x: 0.49212435
#   y: 0.65070194
#   z: -0.05741073
# }
# landmark {
#   x: 0.48242712
#   y: 0.65675575
#   z: -0.04319523
# }
# landmark {
#   x: 0.49849957
#   y: 0.6370345
#   z: -0.0661699
# }
# landmark {
#   x: 0.47101784
#   y: 0.5092799
#   z: -0.008489644
# }
# landmark {
#   x: 0.44864213
#   y: 0.50011796
#   z: -0.0131800305
# }
# landmark {
#   x: 0.42897823
#   y: 0.49906537
#   z: -0.014373877
# }
# landmark {
#   x: 0.4119969
#   y: 0.5031185
#   z: -0.010419293
# }
# landmark {
#   x: 0.3995238
#   y: 0.5122246
#   z: -0.00308208
# }
# landmark {
#   x: 0.3911092
#   y: 0.54713327
#   z: 0.01745479
# }
# landmark {
#   x: 0.35022786
#   y: 0.6008659
#   z: 0.074411415
# }
# landmark {
#   x: 0.40374643
#   y: 0.5747331
#   z: 0.007967978
# }
# landmark {
#   x: 0.41879022
#   y: 0.5797901
#   z: 0.0015219758
# }
# landmark {
#   x: 0.43742836
#   y: 0.57884383
#   z: -0.0022791715
# }
# landmark {
#   x: 0.45474523
#   y: 0.5730393
#   z: -0.003290727
# }
# landmark {
#   x: 0.46826717
#   y: 0.5650694
#   z: -0.0018399992
# }
# landmark {
#   x: 0.47758153
#   y: 0.55743986
#   z: -0.002028413
# }
# landmark {
#   x: 0.3454405
#   y: 0.6025885
#   z: 0.12571779
# }
# landmark {
#   x: 0.4826875
#   y: 0.6622141
#   z: -0.036232904
# }
# landmark {
#   x: 0.4971012
#   y: 0.5985264
#   z: -0.04731255
# }
# landmark {
#   x: 0.5029969
#   y: 0.65109605
#   z: -0.066620916
# }
# landmark {
#   x: 0.51020527
#   y: 0.6605944
#   z: -0.0602284
# }
# landmark {
#   x: 0.50246125
#   y: 0.65437347
#   z: -0.060084127
# }
# landmark {
#   x: 0.4866896
#   y: 0.66824114
#   z: -0.030892653
# }
# landmark {
#   x: 0.51304555
#   y: 0.6623509
#   z: -0.06358268
# }
# landmark {
#   x: 0.51359963
#   y: 0.66652787
#   z: -0.047392182
# }
# landmark {
#   x: 0.47587234
#   y: 0.5417478
#   z: 0.004181049
# }
# landmark {
#   x: 0.48476925
#   y: 0.5456738
#   z: -0.0029504444
# }
# landmark {
#   x: 0.4901943
#   y: 0.5483337
#   z: -0.011565975
# }
# landmark {
#   x: 0.40995908
#   y: 0.53766716
#   z: 0.0047277715
# }
# landmark {
#   x: 0.40201417
#   y: 0.530313
#   z: 0.004645104
# }
# landmark {
#   x: 0.53146446
#   y: 0.58738333
#   z: -0.052341204
# }
# landmark {
#   x: 0.6061502
#   y: 0.5400876
#   z: 0.030813955
# }
# landmark {
#   x: 0.5342741
#   y: 0.6621675
#   z: -0.045276828
# }
# landmark {
#   x: 0.64219
#   y: 0.46134526
#   z: 0.10173864
# }
# landmark {
#   x: 0.56899047
#   y: 0.5580501
#   z: 0.012027158
# }
# landmark {
#   x: 0.58226365
#   y: 0.5593779
#   z: 0.014861767
# }
# landmark {
#   x: 0.59455633
#   y: 0.55759543
#   z: 0.020248821
# }
# landmark {
#   x: 0.6098856
#   y: 0.5468051
#   z: 0.0337822
# }
# landmark {
#   x: 0.5577318
#   y: 0.55266607
#   z: 0.011923868
# }
# landmark {
#   x: 0.58509254
#   y: 0.50955236
#   z: 0.008443627
# }
# landmark {
#   x: 0.57149637
#   y: 0.5108867
#   z: 0.0064245597
# }
# landmark {
#   x: 0.59779775
#   y: 0.5118975
#   z: 0.014925788
# }
# landmark {
#   x: 0.6062332
#   y: 0.518122
#   z: 0.021606717
# }
# landmark {
#   x: 0.61925846
#   y: 0.55787987
#   z: 0.041826032
# }
# landmark {
#   x: 0.5713236
#   y: 0.8215531
#   z: 0.0075120083
# }
# landmark {
#   x: 0.6099619
#   y: 0.53535265
#   z: 0.035941925
# }
# landmark {
#   x: 0.6484331
#   y: 0.5466239
#   z: 0.10804827
# }
# landmark {
#   x: 0.63152176
#   y: 0.54350775
#   z: 0.057472374
# }
# landmark {
#   x: 0.5822119
#   y: 0.63557124
#   z: 4.0995397e-05
# }
# landmark {
#   x: 0.53978735
#   y: 0.7179359
#   z: -0.03540044
# }
# landmark {
#   x: 0.53728294
#   y: 0.7379753
#   z: -0.0289217
# }
# landmark {
#   x: 0.555267
#   y: 0.7228726
#   z: -0.02504229
# }
# landmark {
#   x: 0.5647265
#   y: 0.73010975
#   z: -0.013716634
# }
# landmark {
#   x: 0.5482239
#   y: 0.73818296
#   z: -0.021808423
# }
# landmark {
#   x: 0.5566876
#   y: 0.73939407
#   z: -0.011556732
# }
# landmark {
#   x: 0.5791095
#   y: 0.758831
#   z: 0.008578113
# }
# landmark {
#   x: 0.53557307
#   y: 0.65239674
#   z: -0.069826774
# }
# landmark {
#   x: 0.5368261
#   y: 0.6325507
#   z: -0.07386909
# }
# landmark {
#   x: 0.62606895
#   y: 0.49369818
#   z: 0.028649915
# }
# landmark {
#   x: 0.55459994
#   y: 0.58760864
#   z: -0.0049598017
# }
# landmark {
#   x: 0.56140286
#   y: 0.64616805
#   z: -0.032221943
# }
# landmark {
#   x: 0.56130236
#   y: 0.6357176
#   z: -0.027942782
# }
# landmark {
#   x: 0.618642
#   y: 0.6325767
#   z: 0.023058766
# }
# landmark {
#   x: 0.5343024
#   y: 0.6077806
#   z: -0.06543228
# }
# landmark {
#   x: 0.597873
#   y: 0.4736008
#   z: 0.00010057055
# }
# landmark {
#   x: 0.614825
#   y: 0.47985494
#   z: 0.013562817
# }
# landmark {
#   x: 0.632406
#   y: 0.4252659
#   z: 0.072330736
# }
# landmark {
#   x: 0.5416527
#   y: 0.489645
#   z: -0.018768577
# }
# landmark {
#   x: 0.5593453
#   y: 0.5167906
#   z: 0.009046248
# }
# landmark {
#   x: 0.588134
#   y: 0.7402519
#   z: 0.013316454
# }
# landmark {
#   x: 0.632173
#   y: 0.7278241
#   z: 0.14430518
# }
# landmark {
#   x: 0.5519813
#   y: 0.6576033
#   z: -0.028639909
# }
# landmark {
#   x: 0.5415804
#   y: 0.66444707
#   z: -0.03164501
# }
# landmark {
#   x: 0.5744664
#   y: 0.7413453
#   z: 0.010350318
# }
# landmark {
#   x: 0.56836236
#   y: 0.7403298
#   z: 0.005398124
# }
# landmark {
#   x: 0.6212473
#   y: 0.46565247
#   z: 0.020978462
# }
# landmark {
#   x: 0.5610267
#   y: 0.65484464
#   z: -0.0248755
# }
# landmark {
#   x: 0.5742413
#   y: 0.475008
#   z: -0.011266847
# }
# landmark {
#   x: 0.5766162
#   y: 0.45735013
#   z: -0.013810681
# }
# landmark {
#   x: 0.5843519
#   y: 0.37682205
#   z: 0.011722939
# }
# landmark {
#   x: 0.6270751
#   y: 0.4442837
#   z: 0.04288059
# }
# landmark {
#   x: 0.5794622
#   y: 0.41549972
#   z: -0.0017852685
# }
# landmark {
#   x: 0.6325839
#   y: 0.48400438
#   z: 0.04135339
# }
# landmark {
#   x: 0.63794786
#   y: 0.47334749
#   z: 0.069409266
# }
# landmark {
#   x: 0.53904873
#   y: 0.7297884
#   z: -0.03372941
# }
# landmark {
#   x: 0.5516192
#   y: 0.7322568
#   z: -0.024151495
# }
# landmark {
#   x: 0.5608616
#   y: 0.7350917
#   z: -0.013823306
# }
# landmark {
#   x: 0.54843414
#   y: 0.66137266
#   z: -0.026249686
# }
# landmark {
#   x: 0.57138693
#   y: 0.7410853
#   z: 0.0075607537
# }
# landmark {
#   x: 0.56706005
#   y: 0.744582
#   z: -0.0019673675
# }
# landmark {
#   x: 0.56667656
#   y: 0.7392601
#   z: 0.0047783568
# }
# landmark {
#   x: 0.5469058
#   y: 0.6511249
#   z: -0.047617447
# }
# landmark {
#   x: 0.5534039
#   y: 0.7382055
#   z: -0.009567517
# }
# landmark {
#   x: 0.54492444
#   y: 0.73920417
#   z: -0.016731482
# }
# landmark {
#   x: 0.5348538
#   y: 0.7405676
#   z: -0.023030663
# }
# landmark {
#   x: 0.5411609
#   y: 0.7932769
#   z: -0.011788886
# }
# landmark {
#   x: 0.5408585
#   y: 0.7742076
#   z: -0.025172813
# }
# landmark {
#   x: 0.5400108
#   y: 0.76239693
#   z: -0.027107665
# }
# landmark {
#   x: 0.53843623
#   y: 0.75197893
#   z: -0.024261696
# }
# landmark {
#   x: 0.5367385
#   y: 0.745099
#   z: -0.022212153
# }
# landmark {
#   x: 0.55608165
#   y: 0.74194205
#   z: -0.008939446
# }
# landmark {
#   x: 0.55826306
#   y: 0.7441548
#   z: -0.011275303
# }
# landmark {
#   x: 0.5613581
#   y: 0.7493395
#   z: -0.013048807
# }
# landmark {
#   x: 0.5640024
#   y: 0.75597835
#   z: -0.010139306
# }
# landmark {
#   x: 0.57463866
#   y: 0.70671225
#   z: -0.008093962
# }
# landmark {
#   x: 0.6430392
#   y: 0.6331787
#   z: 0.16580312
# }
# landmark {
#   x: 0.5611067
#   y: 0.7413113
#   z: -0.00097166945
# }
# landmark {
#   x: 0.56386876
#   y: 0.74222964
#   z: -0.0023778367
# }
# landmark {
#   x: 0.53793377
#   y: 0.6736753
#   z: -0.032405708
# }
# landmark {
#   x: 0.55615056
#   y: 0.6671673
#   z: -0.016022164
# }
# landmark {
#   x: 0.5396482
#   y: 0.66926855
#   z: -0.03236888
# }
# landmark {
#   x: 0.56833863
#   y: 0.59875417
#   z: 0.0017074972
# }
# landmark {
#   x: 0.5897361
#   y: 0.6111593
#   z: 0.008525064
# }
# landmark {
#   x: 0.5628512
#   y: 0.6444154
#   z: -0.020133296
# }
# landmark {
#   x: 0.61431324
#   y: 0.39632136
#   z: 0.04043663
# }
# landmark {
#   x: 0.60860795
#   y: 0.42411995
#   z: 0.01953117
# }
# landmark {
#   x: 0.6021422
#   y: 0.4561636
#   z: 0.002988418
# }
# landmark {
#   x: 0.5695869
#   y: 0.77156746
#   z: 0.000797955
# }
# landmark {
#   x: 0.5458832
#   y: 0.461868
#   z: -0.02433557
# }
# landmark {
#   x: 0.54792213
#   y: 0.414536
#   z: -0.016077891
# }
# landmark {
#   x: 0.55003166
#   y: 0.36816934
#   z: -0.0072145048
# }
# landmark {
#   x: 0.6045989
#   y: 0.5538354
#   z: 0.027588027
# }
# landmark {
#   x: 0.631941
#   y: 0.57075477
#   z: 0.051138368
# }
# landmark {
#   x: 0.5506915
#   y: 0.5472566
#   z: 0.013027451
# }
# landmark {
#   x: 0.6198168
#   y: 0.5213313
#   z: 0.035789866
# }
# landmark {
#   x: 0.5455237
#   y: 0.5747399
#   z: -0.011064078
# }
# landmark {
#   x: 0.5548377
#   y: 0.63912266
#   z: -0.046670098
# }
# landmark {
#   x: 0.64326036
#   y: 0.5834449
#   z: 0.06858716
# }
# landmark {
#   x: 0.6251436
#   y: 0.58489394
#   z: 0.037978
# }
# landmark {
#   x: 0.610322
#   y: 0.5925699
#   z: 0.022962471
# }
# landmark {
#   x: 0.58635753
#   y: 0.5905656
#   z: 0.013814036
# }
# landmark {
#   x: 0.5678796
#   y: 0.5830157
#   z: 0.008325228
# }
# landmark {
#   x: 0.55404735
#   y: 0.57386255
#   z: 0.0027827208
# }
# landmark {
#   x: 0.52881575
#   y: 0.5479674
#   z: -0.027942972
# }
# landmark {
#   x: 0.6425581
#   y: 0.62441033
#   z: 0.06502345
# }
# landmark {
#   x: 0.6294864
#   y: 0.5167228
#   z: 0.04381652
# }
# landmark {
#   x: 0.53059775
#   y: 0.66282016
#   z: -0.06346138
# }
# landmark {
#   x: 0.55468035
#   y: 0.6064719
#   z: -0.010718095
# }
# landmark {
#   x: 0.64674664
#   y: 0.54592276
#   z: 0.15512232
# }
# landmark {
#   x: 0.5439017
#   y: 0.56301177
#   z: -0.0005320364
# }
# landmark {
#   x: 0.5628024
#   y: 0.645816
#   z: -0.006369599
# }
# landmark {
#   x: 0.6133298
#   y: 0.5361248
#   z: 0.039245058
# }
# landmark {
#   x: 0.5541005
#   y: 0.62643754
#   z: -0.041517265
# }
# landmark {
#   x: 0.63934946
#   y: 0.67960113
#   z: 0.15903457
# }
# landmark {
#   x: 0.55026597
#   y: 0.5399467
#   z: 0.016542101
# }
# landmark {
#   x: 0.5446963
#   y: 0.61486834
#   z: -0.055964414
# }
# landmark {
#   x: 0.6164871
#   y: 0.7744659
#   z: 0.06586303
# }
# landmark {
#   x: 0.61210907
#   y: 0.79511595
#   z: 0.09146349
# }
# landmark {
#   x: 0.64863396
#   y: 0.6291735
#   z: 0.11587165
# }
# landmark {
#   x: 0.62900966
#   y: 0.74796444
#   z: 0.08581544
# }
# landmark {
#   x: 0.6433389
#   y: 0.50712854
#   z: 0.092773624
# }
# landmark {
#   x: 0.5733303
#   y: 0.83973116
#   z: 0.016581444
# }
# landmark {
#   x: 0.5283425
#   y: 0.667088
#   z: -0.04585005
# }
# landmark {
#   x: 0.5660749
#   y: 0.6205813
#   z: -0.0044665583
# }
# landmark {
#   x: 0.64053774
#   y: 0.54658324
#   z: 0.07284892
# }
# landmark {
#   x: 0.59397614
#   y: 0.5464612
#   z: 0.02097344
# }
# landmark {
#   x: 0.58252156
#   y: 0.5486952
#   z: 0.01620961
# }
# landmark {
#   x: 0.57013357
#   y: 0.74827284
#   z: 0.0008085431
# }
# landmark {
#   x: 0.6400501
#   y: 0.66364247
#   z: 0.068925366
# }
# landmark {
#   x: 0.5504448
#   y: 0.8668638
#   z: 0.017940868
# }
# landmark {
#   x: 0.5836786
#   y: 0.8387587
#   z: 0.050159883
# }
# landmark {
#   x: 0.5969932
#   y: 0.8207698
#   z: 0.06827369
# }
# landmark {
#   x: 0.5711258
#   y: 0.54768294
#   z: 0.014123689
# }
# landmark {
#   x: 0.560474
#   y: 0.5441909
#   z: 0.014687823
# }
# landmark {
#   x: 0.5537644
#   y: 0.5419892
#   z: 0.01682189
# }
# landmark {
#   x: 0.6369399
#   y: 0.5118529
#   z: 0.0588166
# }
# landmark {
#   x: 0.5611291
#   y: 0.52795607
#   z: 0.012304919
# }
# landmark {
#   x: 0.57224053
#   y: 0.52370745
#   z: 0.011046299
# }
# landmark {
#   x: 0.583709
#   y: 0.5225658
#   z: 0.013305172
# }
# landmark {
#   x: 0.5952594
#   y: 0.52512026
#   z: 0.018193055
# }
# landmark {
#   x: 0.60261434
#   y: 0.5294732
#   z: 0.023662161
# }
# landmark {
#   x: 0.6465586
#   y: 0.49916053
#   z: 0.1317892
# }
# landmark {
#   x: 0.60134095
#   y: 0.5432496
#   z: 0.02640495
# }
# landmark {
#   x: 0.5633613
#   y: 0.6952273
#   z: -0.016359128
# }
# landmark {
#   x: 0.5527028
#   y: 0.6544112
#   z: -0.033649463
# }
# landmark {
#   x: 0.54017377
#   y: 0.6905271
#   z: -0.03179105
# }
# landmark {
#   x: 0.60236055
#   y: 0.80002713
#   z: 0.049749568
# }
# landmark {
#   x: 0.58832115
#   y: 0.8198324
#   z: 0.033856854
# }
# landmark {
#   x: 0.55285156
#   y: 0.85506487
#   z: 0.00044545112
# }
# landmark {
#   x: 0.6229532
#   y: 0.7666812
#   z: 0.11958056
# }
# landmark {
#   x: 0.55354923
#   y: 0.53470194
#   z: 0.014815765
# }
# landmark {
#   x: 0.5391548
#   y: 0.5792393
#   z: -0.031037318
# }
# landmark {
#   x: 0.56909937
#   y: 0.8546063
#   z: 0.031510584
# }
# landmark {
#   x: 0.64467776
#   y: 0.67201215
#   z: 0.11326445
# }
# landmark {
#   x: 0.5475787
#   y: 0.7431044
#   z: -0.015996287
# }
# landmark {
#   x: 0.54990804
#   y: 0.74792886
#   z: -0.018293792
# }
# landmark {
#   x: 0.5522867
#   y: 0.75585276
#   z: -0.020370305
# }
# landmark {
#   x: 0.55417657
#   y: 0.76637006
#   z: -0.018101174
# }
# landmark {
#   x: 0.55732864
#   y: 0.7837018
#   z: -0.0069087353
# }
# landmark {
#   x: 0.5637606
#   y: 0.73993397
#   z: -0.0022704217
# }
# landmark {
#   x: 0.5677881
#   y: 0.7383772
#   z: -0.0018067845
# }
# landmark {
#   x: 0.5714923
#   y: 0.7355174
#   z: -0.0014569247
# }
# landmark {
#   x: 0.5838272
#   y: 0.72211397
#   z: 0.0027902343
# }
# landmark {
#   x: 0.6271784
#   y: 0.6744615
#   z: 0.038223267
# }
# landmark {
#   x: 0.5368867
#   y: 0.56011665
#   z: -0.018661669
# }
# landmark {
#   x: 0.54054344
#   y: 0.5247508
#   z: 0.0046431036
# }
# landmark {
#   x: 0.5480051
#   y: 0.5292202
#   z: 0.011506155
# }
# landmark {
#   x: 0.5603533
#   y: 0.7375973
#   z: -0.0012479348
# }
# landmark {
#   x: 0.6268383
#   y: 0.72120386
#   z: 0.058634356
# }
# landmark {
#   x: 0.53058606
#   y: 0.52220047
#   z: -0.014062703
# }
# landmark {
#   x: 0.56458664
#   y: 0.80252373
#   z: 0.0011432441
# }
# landmark {
#   x: 0.53048134
#   y: 0.56862354
#   z: -0.041656993
# }
# landmark {
#   x: 0.54892397
#   y: 0.6100065
#   z: -0.029827135
# }
# landmark {
#   x: 0.5462172
#   y: 0.8143077
#   z: -0.0091040395
# }
# landmark {
#   x: 0.59067523
#   y: 0.7663382
#   z: 0.018010486
# }
# landmark {
#   x: 0.5737296
#   y: 0.66141284
#   z: -0.0019034315
# }
# landmark {
#   x: 0.5787206
#   y: 0.78696847
#   z: 0.0101029165
# }
# landmark {
#   x: 0.602786
#   y: 0.65797186
#   z: 0.0077323006
# }
# landmark {
#   x: 0.58627564
#   y: 0.681025
#   z: 0.0017860953
# }
# landmark {
#   x: 0.6129065
#   y: 0.6895298
#   z: 0.019577635
# }
# landmark {
#   x: 0.551416
#   y: 0.83711296
#   z: -0.0072829616
# }
# landmark {
#   x: 0.55564225
#   y: 0.62120026
#   z: -0.01904109
# }
# landmark {
#   x: 0.6001659
#   y: 0.7796673
#   z: 0.032771703
# }
# landmark {
#   x: 0.58579177
#   y: 0.80166376
#   z: 0.02174928
# }
# landmark {
#   x: 0.60029936
#   y: 0.74197185
#   z: 0.021413118
# }
# landmark {
#   x: 0.63637567
#   y: 0.6970137
#   z: 0.07292885
# }
# landmark {
#   x: 0.61384296
#   y: 0.74331975
#   z: 0.037361737
# }
# landmark {
#   x: 0.63903713
#   y: 0.7115818
#   z: 0.10647549
# }
# landmark {
#   x: 0.5963624
#   y: 0.7069195
#   z: 0.0091590965
# }
# landmark {
#   x: 0.54659814
#   y: 0.59261024
#   z: -0.020132832
# }
# landmark {
#   x: 0.5511532
#   y: 0.6478304
#   z: -0.049970645
# }
# landmark {
#   x: 0.5580133
#   y: 0.65280694
#   z: -0.03461431
# }
# landmark {
#   x: 0.5466745
#   y: 0.63478136
#   z: -0.060614504
# }
# landmark {
#   x: 0.5512088
#   y: 0.5083021
#   z: 0.0016417804
# }
# landmark {
#   x: 0.57225764
#   y: 0.49824587
#   z: 0.0016003426
# }
# landmark {
#   x: 0.59021425
#   y: 0.49629307
#   z: 0.005026368
# }
# landmark {
#   x: 0.60508347
#   y: 0.49879637
#   z: 0.013062577
# }
# landmark {
#   x: 0.6152087
#   y: 0.5066821
#   z: 0.023366682
# }
# landmark {
#   x: 0.6212439
#   y: 0.53958124
#   z: 0.0457904
# }
# landmark {
#   x: 0.65021265
#   y: 0.5876109
#   z: 0.1131494
# }
# landmark {
#   x: 0.6134278
#   y: 0.5667034
#   z: 0.033936713
# }
# landmark {
#   x: 0.60117126
#   y: 0.5725572
#   z: 0.023977498
# }
# landmark {
#   x: 0.5845009
#   y: 0.5735624
#   z: 0.01625734
# }
# landmark {
#   x: 0.5679003
#   y: 0.5694843
#   z: 0.011400489
# }
# landmark {
#   x: 0.5548941
#   y: 0.5627679
#   z: 0.009234857
# }
# landmark {
#   x: 0.546051
#   y: 0.55590916
#   z: 0.007147137
# }
# landmark {
#   x: 0.64448845
#   y: 0.5894767
#   z: 0.16528796
# }
# landmark {
#   x: 0.55682635
#   y: 0.6580091
#   z: -0.027987149
# }
# landmark {
#   x: 0.5409687
#   y: 0.59652746
#   z: -0.041573618
# }
# landmark {
#   x: 0.54357797
#   y: 0.6490705
#   z: -0.06199819
# }
# landmark {
#   x: 0.5357443
#   y: 0.6591323
#   z: -0.05752641
# }
# landmark {
#   x: 0.5426666
#   y: 0.6522263
#   z: -0.05531631
# }
# landmark {
#   x: 0.55281115
#   y: 0.6641846
#   z: -0.02398029
# }
# landmark {
#   x: 0.5341805
#   y: 0.66114837
#   z: -0.061328255
# }
# landmark {
#   x: 0.53191024
#   y: 0.6654219
#   z: -0.045506135
# }
# landmark {
#   x: 0.5459193
#   y: 0.5409643
#   z: 0.013539829
# }
# landmark {
#   x: 0.5389533
#   y: 0.54487205
#   z: 0.004367421
# }
# landmark {
#   x: 0.53604007
#   y: 0.5474483
#   z: -0.005657884
# }
# landmark {
#   x: 0.60684586
#   y: 0.5326811
#   z: 0.02913933
# }
# landmark {
#   x: 0.61271036
#   y: 0.52479136
#   z: 0.030470796
# }

# %%
draw_landmarks(frame, results)

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # 3. Extract Keypoint Values

# %%
len(results.left_hand_landmarks.landmark)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13344\1858948676.py in <module>
# ----> 1 len(results.left_hand_landmarks.landmark)
#
# AttributeError: 'NoneType' object has no attribute 'landmark'

# %%
pose = []
for res in results.pose_landmarks.landmark:
    test = np.array([res.x, res.y, res.z, res.visibility])
    pose.append(test)

# %%
pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)

# %%
# Out:
#   File "C:\Users\FreeComp\AppData\Local\Temp\ipykernel_13344\159585268.py", line 1
#     face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten():
#                                                                                                  ^
# SyntaxError: invalid syntax

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
result_test = extract_keypoints(results)[:10]

# %%
result_test
# Out:
# array([ 0.51471531,  0.63950074, -1.95023513,  0.99924916,  0.5542925 ,
#         0.54314971, -1.89769268,  0.99823779,  0.57853788,  0.53792214])

# %%
468*3+33*4+21*3+21*3
# Out:
# 1662

# %%
np.save('0', result_test)

# %%
np.load('0.npy')
# Out:
# array([ 0.3835876 ,  0.47759178, -0.77978629, ...,  0.        ,
#         0.        ,  0.        ])

# %% [markdown]
# # 4. Setup Folders for Collection

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('C:/Users/FreeComp/Desktop/stem_projects/sign_lang_malak_khaled/ActionDetectionforSignLanguage/data1') 


# Actions that we try to detect
actions = np.array(['hello', 'thanks', 'iloveyou'])

# Thirty videos worth of data
no_sequences = 10

# Videos are going to be 30 frames in length
sequence_length = 1

# %%
cd C:\Users\FreeComp\Desktop\sign_lang_detector\ActionDetectionforSignLanguage
# Out:
# C:\Users\FreeComp\Desktop\sign_lang_detector\ActionDetectionforSignLanguage

# %%
# hello
## 0
## 1
## 2
## ...
## 29
# thanks

# I love you

# %%
cd ..
# Out:
# C:\Users\FreeComp\Desktop\sign_lang_detector\ActionDetectionforSignLanguage

# %%
for action in actions: 
    for sequence in range(no_sequences):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %% [markdown]
# # 5. Collect Keypoint Values for Training and Testing

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)
#                 print(results)

                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(2000)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break

    cap.release()
    cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 6. Preprocess Data and Create Labels and Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'hello': 0, 'thanks': 1, 'iloveyou': 2}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in range(no_sequences):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape
# Out:
# (30, 1, 1662)

# %%
np.array(labels).shape
# Out:
# (30,)

# %%
X = np.array(sequences)

# %%
X.shape
# Out:
# (30, 1, 1662)

# %%
y = to_categorical(labels).astype(int)

# %%
y.shape
# Out:
# (30, 3)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
X_test.shape
# Out:
# (2, 1, 1662)

# %% [markdown]
# # 7. Build and Train LSTM Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(1,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
res = [.7, 0.8, 0.1]

# %%
actions[np.argmax(res)]
# Out:
# 'thanks'

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=100, callbacks=[tb_callback])
# Out:
# Epoch 1/100
# 1/1 [==============================] - 5s 5s/step - loss: 1.0987 - categorical_accuracy: 0.3214
# Epoch 2/100
# 1/1 [==============================] - 1s 966ms/step - loss: 1.0983 - categorical_accuracy: 0.3571
# Epoch 3/100
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0976 - categorical_accuracy: 0.3571
# Epoch 4/100
# 1/1 [==============================] - 0s 16ms/step - loss: 1.0968 - categorical_accuracy: 0.3571
# Epoch 5/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0957 - categorical_accuracy: 0.3571
# Epoch 6/100
# 1/1 [==============================] - 0s 0s/step - loss: 1.0941 - categorical_accuracy: 0.3571
# Epoch 7/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0920 - categorical_accuracy: 0.3571
# Epoch 8/100
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0894 - categorical_accuracy: 0.3571
# Epoch 9/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.0860 - categorical_accuracy: 0.3571
# Epoch 10/100
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0818 - categorical_accuracy: 0.3571
# Epoch 11/100
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0758 - categorical_accuracy: 0.3571
# Epoch 12/100
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0673 - categorical_accuracy: 0.3571
# Epoch 13/100
# 1/1 [==============================] - 0s 17ms/step - loss: 1.0568 - categorical_accuracy: 0.3929
# Epoch 14/100
# 1/1 [==============================] - 0s 17ms/step - loss: 1.0420 - categorical_accuracy: 0.5357
# Epoch 15/100
# 1/1 [==============================] - 0s 17ms/step - loss: 1.0227 - categorical_accuracy: 0.6071
# Epoch 16/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.9973 - categorical_accuracy: 0.6786
# Epoch 17/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.9638 - categorical_accuracy: 0.6786
# Epoch 18/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.9208 - categorical_accuracy: 0.6429
# Epoch 19/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.8695 - categorical_accuracy: 0.6429
# Epoch 20/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.8120 - categorical_accuracy: 0.5714
# Epoch 21/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.7570 - categorical_accuracy: 0.6786
# Epoch 22/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6984 - categorical_accuracy: 0.6071
# Epoch 23/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.6300 - categorical_accuracy: 0.6786
# Epoch 24/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.5692 - categorical_accuracy: 0.6786
# Epoch 25/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5241 - categorical_accuracy: 0.7857
# Epoch 26/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5119 - categorical_accuracy: 0.8214
# Epoch 27/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4237 - categorical_accuracy: 0.8214
# Epoch 28/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3954 - categorical_accuracy: 0.8571
# Epoch 29/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3682 - categorical_accuracy: 0.8929
# Epoch 30/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3321 - categorical_accuracy: 0.8929
# Epoch 31/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.3118 - categorical_accuracy: 0.8929
# Epoch 32/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2886 - categorical_accuracy: 0.8929
# Epoch 33/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2867 - categorical_accuracy: 0.8929
# Epoch 34/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2634 - categorical_accuracy: 0.8929
# Epoch 35/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2628 - categorical_accuracy: 0.8929
# Epoch 36/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2389 - categorical_accuracy: 0.9286
# Epoch 37/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.2496 - categorical_accuracy: 0.8929
# Epoch 38/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2187 - categorical_accuracy: 0.9286
# Epoch 39/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2233 - categorical_accuracy: 0.9286
# Epoch 40/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.2005 - categorical_accuracy: 0.9286
# Epoch 41/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2045 - categorical_accuracy: 0.9643
# Epoch 42/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1826 - categorical_accuracy: 0.9286
# Epoch 43/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1810 - categorical_accuracy: 0.9286
# Epoch 44/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1675 - categorical_accuracy: 0.9643
# Epoch 45/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1652 - categorical_accuracy: 0.9643
# Epoch 46/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1579 - categorical_accuracy: 0.9286
# Epoch 47/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1467 - categorical_accuracy: 0.9643
# Epoch 48/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1527 - categorical_accuracy: 0.9643
# Epoch 49/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1372 - categorical_accuracy: 0.9643
# Epoch 50/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1385 - categorical_accuracy: 0.9643
# Epoch 51/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.1273 - categorical_accuracy: 0.9643
# Epoch 52/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1229 - categorical_accuracy: 0.9643
# Epoch 53/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1221 - categorical_accuracy: 0.9643
# Epoch 54/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.1181 - categorical_accuracy: 0.9643
# Epoch 55/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1115 - categorical_accuracy: 0.9643
# Epoch 56/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1138 - categorical_accuracy: 0.9643
# Epoch 57/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1080 - categorical_accuracy: 0.9643
# Epoch 58/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1079 - categorical_accuracy: 0.9643
# Epoch 59/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.1060 - categorical_accuracy: 0.9643
# Epoch 60/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1024 - categorical_accuracy: 0.9643
# Epoch 61/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1016 - categorical_accuracy: 0.9643
# Epoch 62/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1017 - categorical_accuracy: 0.9643
# Epoch 63/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0989 - categorical_accuracy: 0.9643
# Epoch 64/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0969 - categorical_accuracy: 0.9643
# Epoch 65/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0967 - categorical_accuracy: 0.9643
# Epoch 66/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0962 - categorical_accuracy: 0.9643
# Epoch 67/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0952 - categorical_accuracy: 0.9643
# Epoch 68/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0942 - categorical_accuracy: 0.9643
# Epoch 69/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0933 - categorical_accuracy: 0.9643
# Epoch 70/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0925 - categorical_accuracy: 0.9643
# Epoch 71/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0914 - categorical_accuracy: 0.9643
# Epoch 72/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0899 - categorical_accuracy: 0.9643
# Epoch 73/100
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0888 - categorical_accuracy: 0.9643
# Epoch 74/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0873 - categorical_accuracy: 0.9643
# Epoch 75/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0871 - categorical_accuracy: 0.9643
# Epoch 76/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0857 - categorical_accuracy: 0.9643
# Epoch 77/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0849 - categorical_accuracy: 0.9643
# Epoch 78/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0832 - categorical_accuracy: 0.9643
# Epoch 79/100
# 1/1 [==============================] - 0s 0s/step - loss: 0.0820 - categorical_accuracy: 0.9643
# Epoch 80/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0801 - categorical_accuracy: 0.9643
# Epoch 81/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0784 - categorical_accuracy: 0.9643
# Epoch 82/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0771 - categorical_accuracy: 0.9643
# Epoch 83/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0754 - categorical_accuracy: 0.9643
# Epoch 84/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0725 - categorical_accuracy: 0.9643
# Epoch 85/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0717 - categorical_accuracy: 0.9643
# Epoch 86/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0749 - categorical_accuracy: 0.9643
# Epoch 87/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0638 - categorical_accuracy: 0.9643
# Epoch 88/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0744 - categorical_accuracy: 0.9643
# Epoch 89/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0846 - categorical_accuracy: 0.9643
# Epoch 90/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0632 - categorical_accuracy: 0.9643
# Epoch 91/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0926 - categorical_accuracy: 0.9643
# Epoch 92/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0553 - categorical_accuracy: 0.9643
# Epoch 93/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1183 - categorical_accuracy: 0.9643
# Epoch 94/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3110 - categorical_accuracy: 0.8571
# Epoch 95/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5254 - categorical_accuracy: 0.7857
# Epoch 96/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2371 - categorical_accuracy: 0.8571
# Epoch 97/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.7408 - categorical_accuracy: 0.7857
# Epoch 98/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2107 - categorical_accuracy: 0.9286
# Epoch 99/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0675 - categorical_accuracy: 0.9643
# Epoch 100/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3960 - categorical_accuracy: 0.8214

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 1, 64)             442112
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 1, 128)            98816
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 64)                49408
# _________________________________________________________________
# dense (Dense)                (None, 64)                4160
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 99
# =================================================================
# Total params: 596,675
# Trainable params: 596,675
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 8. Make Predictions

# %%
res = model.predict(X_test)

# %%
actions[np.argmax(res[1])]
# Out:
# 'thanks'

# %%
actions[np.argmax(y_test[1])]
# Out:
# 'thanks'

# %% [markdown]
# # 9. Save Weights

# %%
model.save('C:/Users/FreeComp/Desktop/stem_projects/sign_lang_malak_khaled/ActionDetectionforSignLanguage/action1.h5')

# %%
cd C:\Users\FreeComp\Desktop\sign_lang_detector\ActionDetectionforSignLanguage
# Out:
# C:\Users\FreeComp\Desktop\sign_lang_detector\ActionDetectionforSignLanguage

# %%
del model

# %%
model.load_weights('action.h5')

# %% [markdown]
# # 10. Evaluation using Confusion Matrix and Accuracy

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_train)

# %%
ytrue = np.argmax(y_train,axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
yhat
# Out:
# [2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2]

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[19,  0],
#         [ 9,  0]],
#
#        [[19,  0],
#         [ 9,  0]],
#
#        [[ 0, 18],
#         [ 0, 10]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 0.35714285714285715

# %% [markdown]
# # 11. Test in Real Time

# %%
colors = [(245,117,16), (117,245,16), (16,117,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
plt.figure(figsize=(18,18))
plt.imshow(prob_viz(res, actions, image, colors))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14888\104962489.py in <module>
#       1 plt.figure(figsize=(18,18))
# ----> 2 plt.imshow(prob_viz(res, actions, image, colors))
#
# ~\AppData\Local\Temp\ipykernel_14888\2568779431.py in prob_viz(res, actions, input_frame, colors)
#       3     output_frame = input_frame.copy()
#       4     for num, prob in enumerate(res):
# ----> 5         cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
#       6         cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
#       7
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %%
sequence.reverse()

# %%
len(sequence)
# Out:
# 1

# %%
sequence.append('def')

# %%
sequence.reverse()

# %%
sequence[-30:]
# Out:
# ['def',
#  array([ 0.56178635,  0.58574677, -1.49732101, ...,  0.        ,
#          0.        ,  0.        ])]

# %%
# 1. New detection variables
sequence = []
sentence = []
predictions = []
threshold = 0.5

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            
        #3. Viz logic
            if np.unique(predictions[-10:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# WARNING:tensorflow:Model was constructed with shape (None, 1, 1662) for input KerasTensor(type_spec=TensorSpec(shape=(None, 1, 1662), dtype=tf.float32, name='lstm_input'), name='lstm_input', description="created by layer 'lstm_input'"), but it was called on an input with incompatible shape (None, 30, 1662).
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello

# %%
cd C:\Users\FreeComp\Desktop\sign_lang_detector\ActionDetectionforSignLanguage
# Out:
# C:\Users\FreeComp\Desktop\sign_lang_detector\ActionDetectionforSignLanguage

# %%
#esp way
sequence = []
sentence = []
threshold = 0.8


# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while (1):

        # Read feed
        
        img = cv2.imread('C:/Users/FreeComp/Desktop/stem_projects/sign_lang_malak_khaled/ActionDetectionforSignLanguage/joo.jpg')
        # Make detections
        image, results = mediapipe_detection(img, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
#         sequence.insert(0,keypoints)
#         sequence = sequence[:30]
        sequence.append(keypoints)
        sequence = sequence[-1:]
        
        if len(sequence) == 1:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            
            
        #3. Viz logic
            if res[np.argmax(res)] > threshold: 
                if len(sentence) > 0: 
                    if actions[np.argmax(res)] != sentence[-1]:
                        sentence.append(actions[np.argmax(res)])
                else:
                    sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]
                break;

            # Viz probabilities
#             image = prob_viz(res, actions, image, colors)
            
#         cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
#         cv2.putText(image, ' '.join(sentence), (3,30), 
#                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
#         cv2.imshow('OpenCV Feed', image)

        # Break gracefully
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\array_ops.py in gather(***failed resolving arguments***)
#    4812     # without introducing a circular dependency.
# -> 4813     return params.sparse_read(indices, name=name)
#    4814   except AttributeError:
#
# AttributeError: 'Tensor' object has no attribute 'sparse_read'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14888\2442696709.py in <module>
#      27
#      28         if len(sequence) == 1:
# ---> 29             res = model.predict(np.expand_dims(sequence, axis=0))[0]
#      30             print(actions[np.argmax(res)])
#      31
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1606           use_multiprocessing=use_multiprocessing,
#    1607           model=self,
# -> 1608           steps_per_execution=self._steps_per_execution)
#    1609
#    1610       # Container that configures and calls `tf.keras.Callback`s.
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution)
#    1110         use_multiprocessing=use_multiprocessing,
#    1111         distribution_strategy=ds_context.get_strategy(),
# -> 1112         model=model)
#    1113
#    1114     strategy = ds_context.get_strategy()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     353     indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     354
# --> 355     dataset = self.slice_inputs(indices_dataset, inputs)
#     356
#     357     if shuffle == "batch":
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in slice_inputs(self, indices_dataset, inputs)
#     386
#     387     dataset = dataset.map(
# --> 388         grab_batch, num_parallel_calls=dataset_ops.AUTOTUNE)
#     389
#     390     # Default optimizations are disabled to avoid the overhead of (unnecessary)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in map(self, map_func, num_parallel_calls, deterministic)
#    1810           num_parallel_calls,
#    1811           deterministic,
# -> 1812           preserve_cardinality=True)
#    1813
#    1814   def flat_map(self, map_func):
#
# ~\anaconda3\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in __init__(self, input_dataset, map_func, num_parallel_calls, deterministic, use_inter_op_parallelism, preserve_cardinality, use_legacy_function)
#    4244         self._transformation_name(),
#    4245         dataset=input_dataset,
# -> 4246         use_legacy_function=use_legacy_function)
#    4247     if deterministic is None:
#    4248       self._deterministic = "default"
#
# ~\anaconda3\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in __init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#    3523       with tracking.resource_tracker_scope(resource_tracker):
#    3524         # TODO(b/141462134): Switch to using garbage collection.
# -> 3525         self._function = wrapper_fn.get_concrete_function()
#    3526         if add_to_graph:
#    3527           self._function.add_to_graph(ops.get_default_graph())
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in get_concrete_function(self, *args, **kwargs)
#    3050     """
#    3051     graph_function = self._get_concrete_function_garbage_collected(
# -> 3052         *args, **kwargs)
#    3053     graph_function._garbage_collector.release()  # pylint: disable=protected-access
#    3054     return graph_function
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    3017       args, kwargs = None, None
#    3018     with self._lock:
# -> 3019       graph_function, _ = self._maybe_define_function(args, kwargs)
#    3020       seen_names = set()
#    3021       captured = object_identity.ObjectIdentitySet(
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _maybe_define_function(self, args, kwargs)
#    3359
#    3360           self._function_cache.missed.add(call_context_key)
# -> 3361           graph_function = self._create_graph_function(args, kwargs)
#    3362           self._function_cache.primary[cache_key] = graph_function
#    3363
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3204             arg_names=arg_names,
#    3205             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 3206             capture_by_value=self._capture_by_value),
#    3207         self._function_attributes,
#    3208         function_spec=self.function_spec,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     988         _, original_func = tf_decorator.unwrap(python_func)
#     989
# --> 990       func_outputs = python_func(*func_args, **func_kwargs)
#     991
#     992       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in wrapper_fn(*args)
#    3516           attributes=defun_kwargs)
#    3517       def wrapper_fn(*args):  # pylint: disable=missing-docstring
# -> 3518         ret = _wrapper_helper(*args)
#    3519         ret = structure.to_tensor_list(self._output_structure, ret)
#    3520         return [ops.convert_to_tensor(t) for t in ret]
#
# ~\anaconda3\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in _wrapper_helper(*args)
#    3451         nested_args = (nested_args,)
#    3452
# -> 3453       ret = autograph.tf_convert(func, ag_ctx)(*nested_args)
#    3454       # If `func` returns a list of tensors, `nest.flatten()` and
#    3455       # `ops.convert_to_tensor()` would conspire to attempt to stack
#
# ~\anaconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py in wrapper(*args, **kwargs)
#     665       try:
#     666         with conversion_ctx:
# --> 667           return converted_call(f, args, kwargs, options=options)
#     668       except Exception as e:  # pylint:disable=broad-except
#     669         if hasattr(e, 'ag_error_metadata'):
#
# ~\anaconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     394
#     395   if not options.user_requested and conversion.is_allowlisted(f):
# --> 396     return _call_unconverted(f, args, kwargs, options)
#     397
#     398   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# ~\anaconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     476
#     477   if kwargs is not None:
# --> 478     return f(*args, **kwargs)
#     479   return f(*args)
#     480
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in grab_batch(i, data)
#     383
#     384     def grab_batch(i, data):
# --> 385       return nest.map_structure(lambda d: array_ops.gather(d, i, axis=0), data)
#     386
#     387     dataset = dataset.map(
#
# ~\anaconda3\lib\site-packages\tensorflow\python\util\nest.py in map_structure(func, *structure, **kwargs)
#     657
#     658   return pack_sequence_as(
# --> 659       structure[0], [func(*x) for x in entries],
#     660       expand_composites=expand_composites)
#     661
#
# ~\anaconda3\lib\site-packages\tensorflow\python\util\nest.py in <listcomp>(.0)
#     657
#     658   return pack_sequence_as(
# --> 659       structure[0], [func(*x) for x in entries],
#     660       expand_composites=expand_composites)
#     661
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in <lambda>(d)
#     383
#     384     def grab_batch(i, data):
# --> 385       return nest.map_structure(lambda d: array_ops.gather(d, i, axis=0), data)
#     386
#     387     dataset = dataset.map(
#
# ~\anaconda3\lib\site-packages\tensorflow\python\util\dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\array_ops.py in gather(***failed resolving arguments***)
#    4813     return params.sparse_read(indices, name=name)
#    4814   except AttributeError:
# -> 4815     return gen_array_ops.gather_v2(params, indices, axis, name=name)
#    4816
#    4817
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\gen_array_ops.py in gather_v2(params, indices, axis, batch_dims, name)
#    3799   _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    3800         "GatherV2", params=params, indices=indices, axis=axis,
# -> 3801                     batch_dims=batch_dims, name=name)
#    3802   _result = _outputs[:]
#    3803   if _execute.must_record_gradient():
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     520                 dtype=dtype,
#     521                 as_ref=input_arg.is_ref,
# --> 522                 preferred_dtype=default_dtype)
#     523         except TypeError as err:
#     524           if dtype is None:
#
# ~\anaconda3\lib\site-packages\tensorflow\python\profiler\trace.py in wrapped(*args, **kwargs)
#     161         with Trace(trace_name, **trace_kwargs):
#     162           return func(*args, **kwargs)
# --> 163       return func(*args, **kwargs)
#     164
#     165     return wrapped
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1538
#    1539     if ret is None:
# -> 1540       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1541
#    1542     if ret is NotImplemented:
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\tensor_conversion_registry.py in _default_conversion_function(***failed resolving arguments***)
#      50 def _default_conversion_function(value, dtype, name, as_ref):
#      51   del as_ref  # Unused.
# ---> 52   return constant_op.constant(value, dtype, name=name)
#      53
#      54
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\constant_op.py in constant(value, dtype, shape, name)
#     263   """
#     264   return _constant_impl(value, dtype, shape, name, verify_shape=False,
# --> 265                         allow_broadcast=True)
#     266
#     267
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     285   attrs = {"value": tensor_value, "dtype": dtype_value}
#     286   const_tensor = g._create_op_internal(  # pylint: disable=protected-access
# --> 287       "Const", [], [dtype_value.type], attrs=attrs, name=name).outputs[0]
#     288
#     289   if op_callbacks.should_invoke_op_callbacks():
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     590     return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     591         op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
# --> 592         compute_device)
#     593
#     594   def capture(self, tensor, name=None, shape=None):
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3534           input_types=input_types,
#    3535           original_op=self._default_original_op,
# -> 3536           op_def=op_def)
#    3537       self._create_op_helper(ret, compute_device=compute_device)
#    3538     return ret
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    2014         op_def = self._graph._get_op_def(node_def.op)
#    2015       self._c_op = _create_c_op(self._graph, node_def, inputs,
# -> 2016                                 control_input_ops, op_def)
#    2017       name = compat.as_str(node_def.name)
#    2018     # pylint: enable=protected-access
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in _create_c_op(graph, node_def, inputs, control_inputs, op_def)
#    1851
#    1852   try:
# -> 1853     c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    1854   except errors.InvalidArgumentError as e:
#    1855     # Convert to ValueError for backwards compatibility.
#
# KeyboardInterrupt:

# %%
cap.release()
cv2.destroyAllWindows()

# %%
res[np.argmax(res)] > threshold
# Out:
# True

# %%
(num_sequences,30,1662)

# %%
model.predict(np.expand_dims(X_test[0], axis=0))
# Out:
# array([[5.532469e-04, 9.974770e-01, 1.969744e-03]], dtype=float32)
